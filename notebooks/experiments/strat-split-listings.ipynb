# %% [markdown]
# ## Calculate and split data relative to city population

# %%
import pandas as pd

# %% [markdown]
# #### Load data

# %%
# hashmap containing city as key and tuple as value. Tuple represents address and population values
cities = {
    'vancouver': ('Vancouver, BC, Canada', 664248),
    'surrey': ('Surrey, BC, Canada', 568322),
    'burnaby': ('Burnaby, BC, Canada', 249125),
    'richmond': ('Richmond, BC, Canada', 209937),
    'abbotsford': ('Abbotsford, BC, Canada', 153524)
}

# %%
# load/read data and filter by city
selected_city = 'vancouver'
raw_data_path = '../../data/raw_data/raw_data_Anna_no_duplicates.csv'
listings = pd.read_csv(raw_data_path)
listings_by_city = listings[listings['address'] == cities[selected_city][0]]
print(listings_by_city.shape)
listings_by_city.head()
# Out:
# (773, 25)
#                     id     userId                                        name  \
# 0             36322781   22847334   Cozy Comfy Guest Suite (Nanaimo Skytrain)
# 1             51320938   30084673           NEW, clean, modern, private suite
# 2  1152216438211720822   57959028                 Pet friendly Gem in Gastown
# 3             34203078  258206915  Downtown Vancouver Coal Harbour w/ parking
# 4             21356520   11824155   Private and spacious  room in upper floor
#
#                  address       city  isSuperhost       lat        lng  \
# 0  Vancouver, BC, Canada  Vancouver         True  49.25094 -123.05199
# 1  Vancouver, BC, Canada  Vancouver         True  49.25369 -123.09964
# 2  Vancouver, BC, Canada  Vancouver         True  49.28272 -123.10362
# 3  Vancouver, BC, Canada  Vancouver        False  49.28618 -123.12312
# 4  Vancouver, BC, Canada  Vancouver         True  49.23965 -123.04831
#
#    persons  rating  ...  price_currency price_rate price_total bathrooms  \
# 0        2    4.91  ...             CAD        174         696       1.0
# 1        2    4.92  ...             CAD        224         896       1.0
# 2        3    0.00  ...             CAD        312        1248       1.0
# 3        4    4.76  ...             CAD        469        1873       1.0
# 4        2    4.90  ...             CAD        107         427       1.0
#
#   bedrooms beds                            previewAmenities  \
# 0        1    1  Free parking, Wifi, Kitchen, Self check-in
# 1        1    2                Wifi, Kitchen, Self check-in
# 2        1    1                               Wifi, Kitchen
# 3        1    3  Free parking, Wifi, Kitchen, Self check-in
# 4        1    1                          Free parking, Wifi
#
#                                                 url  \
# 0             https://www.airbnb.com/rooms/36322781
# 1             https://www.airbnb.com/rooms/51320938
# 2  https://www.airbnb.com/rooms/1152216438211720822
# 3             https://www.airbnb.com/rooms/34203078
# 4             https://www.airbnb.com/rooms/21356520
#
#                                               images  \
# 0  ['https://a0.muscache.com/im/pictures/521551d8...
# 1  ['https://a0.muscache.com/im/pictures/400ac6fc...
# 2  ['https://a0.muscache.com/im/pictures/miso/Hos...
# 3  ['https://a0.muscache.com/im/pictures/eaee26aa...
# 4  ['https://a0.muscache.com/im/pictures/edcf7494...
#
#                                           amenityIds
# 0  [1, 4, 8, 9, 522, 77, 79, 657, 85, 86, 23, 89,...
# 1  [1, 33, 34, 35, 4, 100, 8, 40, 41, 44, 45, 51,...
# 2         [1, 33, 35, 99, 179, 4, 36, 37, 8, 12, 47]
# 3  [1, 4, 5, 8, 9, 137, 10, 522, 657, 21, 663, 66...
# 4  [1, 129, 2, 4, 9, 73, 522, 77, 79, 146, 85, 86...
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Calculate city population proportion

# %%
city_pop = cities[selected_city][1]
total_pop = 3332385
city_pop_prop = (city_pop / total_pop) * 100
city_pop_prop
# Out:
# 19.933110970070985

# %% [markdown]
# #### Separate dataset into "entire home" and "room" categories

# %%
entire_homes = listings_by_city[listings_by_city['type'] == 'Entire home']
rooms = listings_by_city[listings_by_city['type'].str.contains('room')]

# just making sure both variables contain the exact same length
if len(entire_homes) > len(rooms):
    entire_homes = entire_homes[:len(rooms)]
else:
    rooms = rooms[:len(entire_homes)]
    
print(entire_homes.shape)
print(rooms.shape)
# Out:
# (99, 25)
# (99, 25)

# %% [markdown]
# #### Split the data data into one dataset 50/50 entire homes and rooms

# %%
# number of desired output items
total_listings_output = 100

def stratified_split():
    total_city_output = round(((city_pop_prop / total_listings_output) * 100) / 2)
    output = [entire_homes[:total_city_output], rooms[:total_city_output]]
    merged_data = pd.concat(output, ignore_index=True)
    return merged_data

output = stratified_split()
output.head()
# Out:
#                     id     userId  \
# 0             51320938   30084673
# 1             53174480    9604504
# 2  1105313155364449856  366130935
# 3             24448342   29063125
# 4   855334363875223252  507075835
#
#                                                 name                address  \
# 0                  NEW, clean, modern, private suite  Vancouver, BC, Canada
# 1   Modern Guest Suite in New Home, Central Location  Vancouver, BC, Canada
# 2                             Vancouver Garden Suite  Vancouver, BC, Canada
# 3           Private Suite in the Heart of Kerrisdale  Vancouver, BC, Canada
# 4  Private & Tranquil Hideaway in Beautiful Vanco...  Vancouver, BC, Canada
#
#         city  isSuperhost        lat         lng  persons  rating  ...  \
# 0  Vancouver         True  49.253690 -123.099640        2    4.92  ...
# 1  Vancouver         True  49.238620 -123.058810        2    4.87  ...
# 2  Vancouver        False  49.279667 -123.081289        2    5.00  ...
# 3  Vancouver         True  49.233570 -123.170070        2    4.70  ...
# 4  Vancouver         True  49.286870 -123.027770        2    4.82  ...
#
#    price_currency price_rate price_total bathrooms bedrooms beds  \
# 0             CAD        224         896       1.0        1    2
# 1             CAD        225         899       1.0        1    1
# 2             CAD        283        1131       1.0        1    1
# 3             CAD        207         827       1.0        0    1
# 4             CAD        242         968       1.0        0    0
#
#                previewAmenities  \
# 0  Wifi, Kitchen, Self check-in
# 1  Wifi, Kitchen, Self check-in
# 2            Free parking, Wifi
# 3  Wifi, Kitchen, Self check-in
# 4  Wifi, Kitchen, Self check-in
#
#                                                 url  \
# 0             https://www.airbnb.com/rooms/51320938
# 1             https://www.airbnb.com/rooms/53174480
# 2  https://www.airbnb.com/rooms/1105313155364449856
# 3             https://www.airbnb.com/rooms/24448342
# 4   https://www.airbnb.com/rooms/855334363875223252
#
#                                               images  \
# 0  ['https://a0.muscache.com/im/pictures/400ac6fc...
# 1  ['https://a0.muscache.com/im/pictures/miso/Hos...
# 2  ['https://a0.muscache.com/im/pictures/hosting/...
# 3  ['https://a0.muscache.com/im/pictures/43d4272a...
# 4  ['https://a0.muscache.com/im/pictures/miso/Hos...
#
#                                           amenityIds
# 0  [1, 33, 34, 35, 4, 100, 8, 40, 41, 44, 45, 51,...
# 1  [1, 4, 8, 137, 394, 522, 77, 79, 145, 657, 146...
# 2  [64, 1, 33, 34, 35, 4, 36, 5, 39, 40, 72, 9, 4...
# 3  [4, 8, 137, 77, 657, 146, 85, 23, 89, 90, 91, ...
# 4  [1, 4, 8, 137, 394, 77, 79, 657, 85, 86, 23, 8...
#
# [5 rows x 25 columns]

# %%
# save to csv
output.to_csv('../../data/raw_data/strat_split.csv')
